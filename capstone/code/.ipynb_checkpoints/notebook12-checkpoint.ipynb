# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from statsbombpy import sb

# %%
sb.competitions()
# Out:
# C:\Users\sunbeams\anaconda3\lib\site-packages\statsbombpy\api_client.py:20: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn("credentials were not supplied. open data access only", NoAuthWarning)
#     competition_id  season_id              country_name  \
# 0               16          4                    Europe
# 1               16          1                    Europe
# 2               16          2                    Europe
# 3               16         27                    Europe
# 4               16         26                    Europe
# 5               16         25                    Europe
# 6               16         24                    Europe
# 7               16         23                    Europe
# 8               16         22                    Europe
# 9               16         21                    Europe
# 10              16         41                    Europe
# 11              16         39                    Europe
# ...

# %%
comp_df = sb.competitions()
# Out:
# C:\Users\sunbeams\anaconda3\lib\site-packages\statsbombpy\api_client.py:20: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn("credentials were not supplied. open data access only", NoAuthWarning)

# %%
comp_df.shape
# Out:
# (42, 12)

# %%
comp_df['competition_name'].unique()
# Out:
# array(['Champions League', "FA Women's Super League", 'FIFA World Cup',
#        'Indian Super league', 'La Liga', 'NWSL', 'Premier League',
#        'UEFA Euro', "UEFA Women's Euro", "Women's World Cup"],
#       dtype=object)

# %%
comp_df[comp_df['competition_name']=='FIFA World Cup']
# Out:
#     competition_id  season_id   country_name competition_name  \
# 18              43          3  International   FIFA World Cup
#
#    competition_gender  competition_youth  competition_international  \
# 18               male              False                       True
#
#    season_name               match_updated        match_updated_360  \
# 18        2018  2022-09-05T17:17:56.670896  2021-06-13T16:17:31.694
#
#    match_available_360             match_available
# 18                None  2022-09-05T17:17:56.670896

# %%
sb.matches(43,3)
# Out:
# C:\Users\sunbeams\anaconda3\lib\site-packages\statsbombpy\api_client.py:20: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn("credentials were not supplied. open data access only", NoAuthWarning)
#     match_id  match_date      kick_off                     competition season  \
# 0       7548  2018-06-22  14:00:00.000  International - FIFA World Cup   2018
# 1       7578  2018-06-15  14:00:00.000  International - FIFA World Cup   2018
# 2       7553  2018-06-23  17:00:00.000  International - FIFA World Cup   2018
# 3       7544  2018-06-20  17:00:00.000  International - FIFA World Cup   2018
# 4       7536  2018-06-18  17:00:00.000  International - FIFA World Cup   2018
# ..       ...         ...           ...                             ...    ...
# 59      7540  2018-06-19  20:00:00.000  International - FIFA World Cup   2018
# 60      8652  2018-07-07  20:00:00.000  International - FIFA World Cup   2018
# ...

# %%
matches_df433 = sb.matches(43,3)
# Out:
# C:\Users\sunbeams\anaconda3\lib\site-packages\statsbombpy\api_client.py:20: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn("credentials were not supplied. open data access only", NoAuthWarning)

# %%
matches_df433.shape
# Out:
# (64, 22)

# %%
# %%time
wc2018events = sb.competition_events(country='International',
                                     division='FIFA World Cup',
                                     season='2018',
                                     gender='male',
                                     split=True
                                    )
# Out:
# C:\Users\sunbeams\anaconda3\lib\site-packages\statsbombpy\api_client.py:20: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn("credentials were not supplied. open data access only", NoAuthWarning)

# %%
wc2018events.keys()
# Out:
# dict_keys(['starting_xis', 'half_starts', 'passes', 'ball_receipts', 'carrys', 'pressures', 'duels', 'blocks', 'ball_recoverys', 'foul_committeds', 'foul_wons', 'camera_ons', 'dribbles', 'miscontrols', 'shots', 'goal_keepers', 'interceptions', 'dispossesseds', 'clearances', 'player_offs', 'player_ons', 'camera_offs', 'dribbled_pasts', '50/50s', 'offsides', 'shields', 'half_ends', 'substitutions', 'tactical_shifts', 'injury_stoppages', 'bad_behaviours', 'errors', 'referee_ball_drops', 'own_goal_fors', 'own_goal_againsts'])

# %%
shots_df = wc2018events['shots']

# %%
shots_df.shape
# Out:
# (1706, 35)

# %%
len(shots_df[shots_df['shot_outcome'] == 'Goal'])
# Out:
# 183

# %%
shots_df.columns
# Out:
# Index(['id', 'index', 'period', 'timestamp', 'minute', 'second', 'type',
#        'possession', 'possession_team', 'play_pattern', 'team', 'player',
#        'position', 'location', 'duration', 'related_events', 'match_id',
#        'shot_statsbomb_xg', 'shot_end_location', 'shot_type', 'shot_outcome',
#        'shot_technique', 'shot_body_part', 'shot_freeze_frame',
#        'possession_team_id', 'player_id', 'under_pressure', 'shot_key_pass_id',
#        'shot_first_time', 'shot_aerial_won', 'shot_open_goal',
#        'shot_one_on_one', 'shot_deflected', 'shot_redirect',
#        'shot_follows_dribble'],
#       dtype='object')

# %%
plt.hist(shots_df[shots_df['shot_outcome']=='Goal'][['shot_statsbomb_xg']])
# Out:
# (array([46., 33., 21., 11.,  5.,  6.,  4.,  0., 53.,  4.]),
#  array([0.01230608, 0.10424951, 0.19619294, 0.28813637, 0.38007981,
#         0.47202324, 0.56396667, 0.6559101 , 0.74785354, 0.83979697,
#         0.9317404 ]),
#  <BarContainer object of 10 artists>)

# %%
comp_df[comp_df['competition_name']=='Premier League']

# %%
sb.matches(2,44)

# %%
comp_df[comp_df['competition_name']=='UEFA Euro']

# %%
sb.matches(55,43)

# %%
comp_df[comp_df['competition_name']=='Champions League']

# %%
sb.matches(16,4)

# %%
comp_df[comp_df['competition_name']=='La Liga']

# %%
sb.matches(11,90)

# %%
sb.lineups(22912)['Liverpool']

# %%
sb.events(22912)
